# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Load the "autoreload" extension so that code can change
# %load_ext autoreload

#always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

from src.data import make_dataset

# %%
import pandas as pd

# %% [markdown]
# # 2- Data Exploration

# %%
input_path = "/Users/jbaripatti/machine_learning_proj/data/raw/"
input_filename = "MiniBooNE_PID.txt"
input_filepath = input_path + input_filename

# %%
output_path = "/Users/jbaripatti/machine_learning_proj/data/interim/"
output_name = 'data_interim.txt'
output_filepath = output_path + output_name

# %%
data = make_dataset.make_dataset(input_filepath, output_filepath)

# %%
data.shape
# Out:
# (130064, 51)

# %%
# I will use a dataframe for the data exploration
#Each line, after the first line has the 50 particle ID variables for one event.
column_names = ['ID_' + str(i) for i in range(1,51)]
column_names.append('is_signal')

# %%
df = pd.DataFrame(data=data, columns=column_names)

# %%
df.head()
# Out:
#       ID_1      ID_2      ID_3      ID_4      ID_5      ID_6      ID_7  \
# 0  2.59413  0.468803   20.6916  0.322648  0.009682  0.374393  0.803479
# 1  3.86388  0.645781   18.1375  0.233529  0.030733  0.361239  1.069740
# 2  3.38584  1.197140   36.0807  0.200866  0.017341  0.260841  1.108950
# 3  4.28524  0.510155  674.2010  0.281923  0.009174  0.000000  0.998822
# 4  5.93662  0.832993   59.8796  0.232853  0.025066  0.233556  1.370040
#
#        ID_8     ID_9     ID_10  ...    ID_42     ID_43    ID_44     ID_45  \
# 0  0.896592  3.59665  0.249282  ... -31.3730  0.442259  5.86453  0.000000
# 1  0.878714  3.59243  0.200793  ...  45.9597 -0.478507  6.11126  0.001182
# 2  0.884405  3.43159  0.177167  ... -11.5608 -0.297008  8.27204  0.003854
# 3  0.823390  3.16382  0.171678  ... -18.4586  0.453886  2.48112  0.000000
# 4  0.787424  3.66546  0.174862  ...  42.9600 -0.975752  2.66109  0.000000
#
#       ID_46     ID_47     ID_48     ID_49     ID_50  is_signal
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130064 entries, 0 to 130063
# Data columns (total 51 columns):
# ID_1         130064 non-null float64
# ID_2         130064 non-null float64
# ID_3         130064 non-null float64
# ID_4         130064 non-null float64
# ID_5         130064 non-null float64
# ID_6         130064 non-null float64
# ID_7         130064 non-null float64
# ID_8         130064 non-null float64
# ID_9         130064 non-null float64
# ID_10        130064 non-null float64
# ID_11        130064 non-null float64
# ID_12        130064 non-null float64
# ID_13        130064 non-null float64
# ID_14        130064 non-null float64
# ID_15        130064 non-null float64
# ID_16        130064 non-null float64
# ID_17        130064 non-null float64
# ID_18        130064 non-null float64
# ID_19        130064 non-null float64
# ID_20        130064 non-null float64
# ID_21        130064 non-null float64
# ID_22        130064 non-null float64
# ...

# %%
df.describe()
# Out:
#                 ID_1           ID_2           ID_3           ID_4  \
# count  130064.000000  130064.000000  130064.000000  130064.000000
# mean        1.251799      -2.107551     123.795041      -3.312518
# std        60.119987      59.913094     196.010686      59.834554
# min      -999.000000    -999.000000    -999.000000    -999.000000
# 25%         4.012528       0.876346      49.295075       0.241571
# 50%         4.787715       1.381965     106.135500       0.272089
# 75%         5.628298       1.947870     138.849250       0.315095
# max        17.057300       8.802820    4747.670000       0.736804
#
#                 ID_5           ID_6           ID_7           ID_8  \
# count  130064.000000  130064.000000  130064.000000  130064.000000
# mean       -3.585353      -3.434412      -2.627901      -2.773691
# std        59.818130      59.827325      59.876644      59.866946
# min      -999.000000    -999.000000    -999.000000    -999.000000
# ...

# %%
# %matplotlib inline

# %%
df.hist(figsize=(15,15))
plt.title('A histogram for each particle ID variable')
plt.savefig('/Users/jbaripatti/machine_learning_proj/reports/figures/data_viz_hist.png')

# %%
df.sample(frac=0.1).plot(kind='density', figsize=(15,20),subplots=True, layout=(17,3), sharex=False, sharey=False)
plt.title("Signal density of a sample dataset")
plt.savefig('/Users/jbaripatti/machine_learning_proj/reports/figures/signal_density.png')
plt.show()

# %%
# Create a Test Set
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(data, test_size=0.2, random_state=42)

# %%
X_train = train_set[:,0:-1]

# %%
X_train.shape
# Out:
# (104051, 50)

# %%
data.shape
# Out:
# (130064, 51)

# %%
X_train, y_train, X_test, y_test = make_dataset.split_data(data)

# %%
y_train[:5]
# Out:
# array([1., 1., 0., 0., 0.])
